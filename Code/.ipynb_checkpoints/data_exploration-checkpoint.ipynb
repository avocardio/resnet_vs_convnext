# %% [markdown]
# <a href="https://colab.research.google.com/github/avocardio/Project/blob/main/data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import shutil
import matplotlib.pyplot as plt
import zipfile
from tensorflow.keras.preprocessing import image
# %matplotlib inline

from sklearn.decomposition import PCA
from math import ceil
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# Input In [2], in <module>
#       8 import matplotlib.pyplot as plt
#       9 import zipfile
# ---> 10 from tensorflow.keras.preprocessing import image
#      11 get_ipython().run_line_magic('matplotlib', 'inline')
#      13 from sklearn.decomposition import PCA
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\api\_v2\keras\__init__.py:8, in <module>
#       3 """Public API for tf.keras namespace.
#       4 """
#       6 import sys as _sys
# ----> 8 from keras import __version__
#       9 from keras.api._v2.keras import __internal__
#      10 from keras.api._v2.keras import activations
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\__init__.py:25, in <module>
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      27 from keras.engine.input_layer import Input
#      28 from keras.engine.sequential import Sequential
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\models.py:20, in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\metrics.py:24, in <module>
#      21 from typing import List, Tuple, Union
#      22 import warnings
# ---> 24 from keras import activations
#      25 from keras import backend
#      26 from keras.engine import base_layer
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\activations.py:20, in <module>
#      17 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\layers\__init__.py:23, in <module>
#      20 from tensorflow.python import tf2
#      22 # Generic layers.
# ---> 23 from keras.engine.input_layer import Input
#      24 from keras.engine.input_layer import InputLayer
#      25 from keras.engine.input_spec import InputSpec
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\engine\input_layer.py:21, in <module>
#      19 from keras import backend
#      20 from keras.distribute import distributed_training_utils
# ---> 21 from keras.engine import base_layer
#      22 from keras.engine import keras_tensor
#      23 from keras.engine import node as node_module
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\engine\base_layer.py:43, in <module>
#      41 from keras.engine import node as node_module
#      42 from keras.mixed_precision import autocast_variable
# ---> 43 from keras.mixed_precision import loss_scale_optimizer
#      44 from keras.mixed_precision import policy
#      45 from keras.saving.saved_model import layer_serialization
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\mixed_precision\loss_scale_optimizer.py:18, in <module>
#      15 """Contains the loss scaling optimizer class."""
#      17 from keras import backend
# ---> 18 from keras import optimizers
#      19 from keras.mixed_precision import loss_scale as keras_loss_scale_module
#      20 from keras.optimizer_experimental import optimizer as optimizer_experimental
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\optimizers.py:31, in <module>
#      29 from keras.optimizer_v1 import Optimizer
#      30 from keras.optimizer_v1 import TFOptimizer
# ---> 31 from keras.optimizer_v2 import adadelta as adadelta_v2
#      32 from keras.optimizer_v2 import adagrad as adagrad_v2
#      33 from keras.optimizer_v2 import adam as adam_v2
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\optimizer_v2\adadelta.py:22, in <module>
#      20 import numpy as np
#      21 from keras import backend_config
# ---> 22 from keras.optimizer_v2 import optimizer_v2
#      23 from tensorflow.python.util.tf_export import keras_export
#      26 @keras_export('keras.optimizers.Adadelta')
#      27 class Adadelta(optimizer_v2.OptimizerV2):
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:36, in <module>
#      32 import tensorflow.compat.v2 as tf
#      33 from tensorflow.python.util.tf_export import keras_export
# ---> 36 keras_optimizers_gauge = tf.__internal__.monitoring.BoolGauge(
#      37     "/tensorflow/api/keras/optimizers", "keras optimizer usage", "method")
#      39 _DEFAULT_VALID_DTYPES = frozenset([
#      40     tf.float16, tf.bfloat16, tf.float32, tf.float64,
#      41     tf.complex64, tf.complex128
#      42 ])
#      45 def _deduplicate_indexed_slices(values, indices):
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\tensorflow\python\eager\monitoring.py:360, in BoolGauge.__init__(self, name, description, *labels)
#     352 def __init__(self, name, description, *labels):
#     353   """Creates a new BoolGauge.
#     354
#     355   Args:
#    (...)
#     358     *labels: The label list of the new metric.
#     359   """
# --> 360   super(BoolGauge, self).__init__('BoolGauge', _bool_gauge_methods,
#     361                                   len(labels), name, description, *labels)
#
# File ~\anaconda3\envs\iannwtf\lib\site-packages\tensorflow\python\eager\monitoring.py:135, in Metric.__init__(self, metric_name, metric_methods, label_length, *args)
#     131 if label_length >= len(self._metric_methods):
#     132   raise ValueError('Cannot create {} metric with label >= {}'.format(
#     133       self._metric_name, len(self._metric_methods)))
# --> 135 self._metric = self._metric_methods[self._label_length].create(*args)
#
# AlreadyExistsError: Another metric with the same name already exists.

# %% [markdown]
# ## Load data
# The dataset is already splitted into train and validation data and reduced to 10 classes with 100 images per class.

# %%
DIR_TRAIN = '../Data/Use/Train/'
DIR_VALID = '../Data/Use/Valid/'

# %% [markdown]
# ## Data Exploration
#
# The ideas of data exploration are based on this blogpost:
# https://towardsdatascience.com/exploratory-data-analysis-ideas-for-image-classification-d3fc6bbfb2d2
#
# Before starting with training our classification models, we want to explore our dataset to get a basic understanding of the classes and images we deal with. We aim to grasp the structure of our data better to identify necessary preprocessing steps as well as guiding our modelling process.

# %% [markdown]
# ### Raw Images
# Show random samples of the bird classes.

# %%
# function for printing dictionary length per item in a nice way
def print_length_dictionary(dct, which_set):
    print('Number of images per {} class:'.format(which_set))
    for item, value in dct.items():
        print("{} : {}".format(item, value))

# %%
# use the training data for data exploration
data_dir_train = DIR_TRAIN

# store the bird names in a list
bird_names = [name for name in os.listdir(data_dir_train)]

# dictionaries for storing the images belonging to each bird class and randomly selected for plotting
bird_dic = {}
select_dic = {}

print('The bird classes are: ')

# for each bird class do
for name in bird_names:
  print(name)

  # get the list of jpgs
  bird_dic[name] = [fn for fn in os.listdir('{}/{}'.format(data_dir_train, name)) if fn.endswith('jpg')]

  # randomly select 3 images
  select_dic[name] = np.random.choice(bird_dic[name], 3, replace = False)

# number of images per training class
lengths_dic = {key:len(value) for key,value in iter(bird_dic.items())}
print()
print_length_dictionary(lengths_dic, 'train')

# plotting 10 x 3 image matrix
fig = plt.figure(figsize = (80,60))
for i in range(30):
    if i < 3:
        fp = '{}/CASPIAN TERN/{}'.format(data_dir_train, select_dic['CASPIAN TERN'][i])
        label = 'CASPIAN TERN'
    elif i >= 3 and i < 6:
        fp = '{}/D-ARNAUDS BARBET/{}'.format(data_dir_train, select_dic['D-ARNAUDS BARBET'][i-3])
        label = 'D-ARNAUDS BARBET'
    elif i >= 6 and i < 9:
        fp = '{}/DARK EYED JUNCO/{}'.format(data_dir_train, select_dic['DARK EYED JUNCO'][i-6])
        label = 'DARK EYED JUNCO'
    elif i >= 9 and i < 12:
        fp = '{}/HOUSE FINCH/{}'.format(data_dir_train, select_dic['HOUSE FINCH'][i-9])
        label = 'HOUSE FINCH'
    elif i >= 12 and i < 15:
        fp = '{}/OVENBIRD/{}'.format(data_dir_train, select_dic['OVENBIRD'][i-12])
        label = 'OVENBIRD'
    elif i >= 15 and i < 18:
        fp = '{}/OYSTER CATCHER/{}'.format(data_dir_train, select_dic['OYSTER CATCHER'][i-15])
        label = 'OYSTER CATCHER'
    elif i >= 18 and i < 21:
        fp = '{}/RED TAILED HAWK/{}'.format(data_dir_train, select_dic['RED TAILED HAWK'][i-18])
        label = 'RED TAILED HAWK'
    elif i >= 21 and i < 24:
        fp = '{}/SWINHOES PHEASANT/{}'.format(data_dir_train, select_dic['SWINHOES PHEASANT'][i-21])
        label = 'SWINHOES PHEASANT'
    elif i >= 24 and i < 27:
        fp = '{}/VIOLET GREEN SWALLOW/{}'.format(data_dir_train, select_dic['VIOLET GREEN SWALLOW'][i-24])
        label = 'VIOLET GREEN SWALLOW'
    else:
        fp = '{}/WOOD DUCK/{}'.format(data_dir_train, select_dic['WOOD DUCK'][i-27])
        label = 'WOOD DUCK'
    ax = fig.add_subplot(10, 3, i+1)
    
    fn = image.load_img(fp, target_size = (100,100), color_mode='rgb')
    plt.imshow(fn)
    plt.title(label)
    plt.axis('off')
plt.show()
# Out:
# The bird classes are:
# CASPIAN TERN
# D-ARNAUDS BARBET
# DARK EYED JUNCO
# HOUSE FINCH
# OVENBIRD
# OYSTER CATCHER
# RED TAILED HAWK
# SWINHOES PHEASANT
# VIOLET GREEN SWALLOW
# WOOD DUCK
#
# Number of images per train class:
# CASPIAN TERN : 100
# D-ARNAUDS BARBET : 100
# DARK EYED JUNCO : 100
# HOUSE FINCH : 100
# OVENBIRD : 100
# OYSTER CATCHER : 100
# RED TAILED HAWK : 100
# SWINHOES PHEASANT : 100
# VIOLET GREEN SWALLOW : 100
# WOOD DUCK : 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <module>
#      60     label = 'WOOD DUCK'
#      61 ax = fig.add_subplot(10, 3, i+1)
# ---> 63 fn = image.load_img(fp, target_size = (100,100), color_mode='rgb')
#      64 plt.imshow(fn)
#      65 plt.title(label)
#
# NameError: name 'image' is not defined

# %% [markdown]
# ### Images as Matrix
# Convert the images into matrices of pixel values. The matrices will have the size (number of images per class x number of pixels).

# %%
# make nxm matrix (pixel size per image is reduced to a default of 64x64)
def img2np(path, list_of_filename, size = (64, 64)):
    # iterating through each file
    for fn in list_of_filename:
        fp = path + fn
        current_image = image.load_img(fp, target_size = size, 
                                       color_mode = 'grayscale')
        # covert image to a matrix
        img_ts = image.img_to_array(current_image)
        # turn that into a vector / 1D array
        img_ts = [img_ts.ravel()]
        try:
            # concatenate different images
            full_mat = np.concatenate((full_mat, img_ts))
        except UnboundLocalError: 
            # if not assigned yet, assign one
            full_mat = img_ts
    return full_mat

pixel_dic = {}

# run on the bird folders
for name in bird_names:
  pixel_dic[name] = img2np('{}/{}/'.format(data_dir_train, name), bird_dic[name])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <module>
#      22 # run on the bird folders
#      23 for name in bird_names:
# ---> 24   pixel_dic[name] = img2np('{}/{}/'.format(data_dir_train, name), bird_dic[name])
#
# Input In [21], in img2np(path, list_of_filename, size)
#       4 for fn in list_of_filename:
#       5     fp = path + fn
# ----> 6     current_image = image.load_img(fp, target_size = size,
#       7                                    color_mode = 'grayscale')
#       8     # covert image to a matrix
#       9     img_ts = image.img_to_array(current_image)
#
# NameError: name 'image' is not defined

# %% [markdown]
# ### Average Image per class
# Show the average image per class by taking the average value of each pixel across all images per class.

# %%
def find_mean_img(full_mat, title, size = (64, 64)):
    # calculate the average
    mean_img = np.mean(full_mat, axis = 0)
    # reshape it back to a matrix
    mean_img = mean_img.reshape(size)
    plt.imshow(mean_img, vmin=0, vmax=255, cmap='Greys_r')
    plt.title(f'Average {title}')
    plt.axis('off')
    plt.show()
    return mean_img

mean_dic = {}

for name in bird_names:
  mean_dic[name] = find_mean_img(pixel_dic[name], name)

# %% [markdown]
# ### Eigenimages
#
# Uses PCA to visualize the components that describe 70% of each class best.

# %%
def eigenimages(full_mat, title, n_comp = 0.7, size = (64, 64)):
    # fit PCA to describe n_comp * variability in the class
    pca = PCA(n_components = n_comp, whiten = True)
    pca.fit(full_mat)
    print(title)
    print('Number of PC: ', pca.n_components_)
    return pca
  
def plot_pca(pca, size = (64, 64)):
    # plot eigenimages in a grid
    n = pca.n_components_
    fig = plt.figure(figsize=(8, 8))
    r = int(n**.5)
    c = ceil(n/ r)
    for i in range(n):
        ax = fig.add_subplot(r, c, i + 1, xticks = [], yticks = [])
        ax.imshow(pca.components_[i].reshape(size), 
                  cmap='Greys_r')
    plt.axis('off')
    plt.show()
    
for name in bird_names:
  plot_pca(eigenimages(pixel_dic[name], name))
# Out:
# CASPIAN TERN has 14 principal components
# Number of PC:  14
# D-ARNAUDS BARBET has 27 principal components
# Number of PC:  27
# DARK EYED JUNCO has 16 principal components
# Number of PC:  16
# HOUSE FINCH has 18 principal components
# Number of PC:  18
# OVENBIRD has 27 principal components
# Number of PC:  27
# OYSTER CATCHER has 18 principal components
# Number of PC:  18
# RED TAILED HAWK has 20 principal components
# Number of PC:  20
# SWINHOES PHEASANT has 24 principal components
# Number of PC:  24
# VIOLET GREEN SWALLOW has 18 principal components
# Number of PC:  18
# WOOD DUCK has 29 principal components
# Number of PC:  29
